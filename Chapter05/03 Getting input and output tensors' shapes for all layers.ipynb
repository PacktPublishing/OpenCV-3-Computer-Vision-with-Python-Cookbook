# %%
import cv2
import numpy as np

# %%
net = cv2.dnn.readNetFromCaffe('../data/bvlc_googlenet.prototxt', 
                               '../data/bvlc_googlenet.caffemodel')

if not net.empty():
    print('Net loaded successfully\n')
    
print('Net contains:')
for t in net.getLayerTypes():
    print('\t%d layers of type %s' % (net.getLayersCount(t), t))
# Out:
# Net loaded successfully
#
# Net contains:
# 	9 layers of type Concat
# 	57 layers of type Convolution
# 	1 layers of type Dropout
# 	1 layers of type InnerProduct
# 	2 layers of type LRN
# 	14 layers of type Pooling
# 	57 layers of type ReLU
# 	1 layers of type Softmax
# 	1 layers of type __NetInputLayer__

# %%
layers_ids, in_shapes, out_shapes = net.getLayersShapes([1, 3, 224, 224])

layers_names = net.getLayerNames()

print('Net layers shapes:')
for l in range(len(layers_names)):
    in_num, out_num = len(in_shapes[l]), len(out_shapes[l])
    print('Layer "%s" has %d input(s) and %d output(s)' 
          % (layers_names[l], in_num, out_num))
    for i in range(in_num):
        print('\tinput #%d has shape' % i, in_shapes[l][i].flatten())
    
    for i in range(out_num):
        print('\toutput #%d has shape' % i, out_shapes[l][i].flatten())
# Out:
# Net layers shapes:
# Layer "conv1/7x7_s2" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1   3 224 224]
# 	output #0 has shape [  1   3 224 224]
# Layer "conv1/relu_7x7" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1   3 224 224]
# 	output #0 has shape [  1  64 112 112]
# Layer "pool1/3x3_s2" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1  64 112 112]
# 	output #0 has shape [  1  64 112 112]
# Layer "pool1/norm1" has 1 input(s) and 2 output(s)
# 	input #0 has shape [  1  64 112 112]
# 	output #0 has shape [ 1 64 56 56]
# 	output #1 has shape [ 1 64 56 56]
# Layer "conv2/3x3_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
# Layer "conv2/relu_3x3_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
# Layer "conv2/3x3" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [ 1 64 56 56]
# Layer "conv2/relu_3x3" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 64 56 56]
# 	output #0 has shape [  1 192  56  56]
# Layer "conv2/norm2" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 192  56  56]
# 	output #0 has shape [  1 192  56  56]
# Layer "pool2/3x3_s2" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 192  56  56]
# 	output #0 has shape [  1 192  56  56]
# Layer "inception_3a/1x1" has 1 input(s) and 2 output(s)
# 	input #0 has shape [  1 192  56  56]
# 	output #0 has shape [  1 192  28  28]
# 	output #1 has shape [  1 192  28  28]
# Layer "inception_3a/relu_1x1" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 192  28  28]
# 	output #0 has shape [ 1 64 28 28]
# Layer "inception_3a/3x3_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 64 28 28]
# 	output #0 has shape [ 1 64 28 28]
# Layer "inception_3a/relu_3x3_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 192  28  28]
# 	output #0 has shape [ 1 96 28 28]
# Layer "inception_3a/3x3" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 96 28 28]
# 	output #0 has shape [ 1 96 28 28]
# Layer "inception_3a/relu_3x3" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 96 28 28]
# 	output #0 has shape [  1 128  28  28]
# Layer "inception_3a/5x5_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
# Layer "inception_3a/relu_5x5_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 192  28  28]
# 	output #0 has shape [ 1 16 28 28]
# Layer "inception_3a/5x5" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 16 28 28]
# 	output #0 has shape [ 1 16 28 28]
# Layer "inception_3a/relu_5x5" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 16 28 28]
# 	output #0 has shape [ 1 32 28 28]
# Layer "inception_3a/pool" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 32 28 28]
# 	output #0 has shape [ 1 32 28 28]
# Layer "inception_3a/pool_proj" has 1 input(s) and 2 output(s)
# 	input #0 has shape [  1 192  28  28]
# 	output #0 has shape [  1 192  28  28]
# 	output #1 has shape [  1 192  28  28]
# Layer "inception_3a/relu_pool_proj" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 192  28  28]
# 	output #0 has shape [ 1 32 28 28]
# Layer "inception_3a/output" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 32 28 28]
# 	output #0 has shape [ 1 32 28 28]
# Layer "inception_3b/1x1" has 4 input(s) and 1 output(s)
# 	input #0 has shape [ 1 64 28 28]
# 	input #1 has shape [  1 128  28  28]
# 	input #2 has shape [ 1 32 28 28]
# 	input #3 has shape [ 1 32 28 28]
# 	output #0 has shape [  1 256  28  28]
# Layer "inception_3b/relu_1x1" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 256  28  28]
# 	output #0 has shape [  1 128  28  28]
# Layer "inception_3b/3x3_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
# Layer "inception_3b/relu_3x3_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 256  28  28]
# 	output #0 has shape [  1 128  28  28]
# Layer "inception_3b/3x3" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 128  28  28]
# Layer "inception_3b/relu_3x3" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 128  28  28]
# 	output #0 has shape [  1 192  28  28]
# Layer "inception_3b/5x5_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 192  28  28]
# 	output #0 has shape [  1 192  28  28]
# Layer "inception_3b/relu_5x5_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 256  28  28]
# 	output #0 has shape [ 1 32 28 28]
# Layer "inception_3b/5x5" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 32 28 28]
# 	output #0 has shape [ 1 32 28 28]
# Layer "inception_3b/relu_5x5" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 32 28 28]
# 	output #0 has shape [ 1 96 28 28]
# Layer "inception_3b/pool" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 96 28 28]
# 	output #0 has shape [ 1 96 28 28]
# Layer "inception_3b/pool_proj" has 1 input(s) and 2 output(s)
# 	input #0 has shape [  1 256  28  28]
# 	output #0 has shape [  1 256  28  28]
# 	output #1 has shape [  1 256  28  28]
# Layer "inception_3b/relu_pool_proj" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 256  28  28]
# 	output #0 has shape [ 1 64 28 28]
# Layer "inception_3b/output" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 64 28 28]
# 	output #0 has shape [ 1 64 28 28]
# Layer "pool3/3x3_s2" has 4 input(s) and 1 output(s)
# 	input #0 has shape [  1 128  28  28]
# 	input #1 has shape [  1 192  28  28]
# 	input #2 has shape [ 1 96 28 28]
# 	input #3 has shape [ 1 64 28 28]
# 	output #0 has shape [  1 480  28  28]
# Layer "inception_4a/1x1" has 1 input(s) and 2 output(s)
# 	input #0 has shape [  1 480  28  28]
# 	output #0 has shape [  1 480  14  14]
# 	output #1 has shape [  1 480  14  14]
# Layer "inception_4a/relu_1x1" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 480  14  14]
# 	output #0 has shape [  1 192  14  14]
# Layer "inception_4a/3x3_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 192  14  14]
# 	output #0 has shape [  1 192  14  14]
# Layer "inception_4a/relu_3x3_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 480  14  14]
# 	output #0 has shape [ 1 96 14 14]
# Layer "inception_4a/3x3" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 96 14 14]
# 	output #0 has shape [ 1 96 14 14]
# Layer "inception_4a/relu_3x3" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 96 14 14]
# 	output #0 has shape [  1 208  14  14]
# Layer "inception_4a/5x5_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 208  14  14]
# 	output #0 has shape [  1 208  14  14]
# Layer "inception_4a/relu_5x5_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 480  14  14]
# 	output #0 has shape [ 1 16 14 14]
# Layer "inception_4a/5x5" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 16 14 14]
# 	output #0 has shape [ 1 16 14 14]
# Layer "inception_4a/relu_5x5" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 16 14 14]
# 	output #0 has shape [ 1 48 14 14]
# Layer "inception_4a/pool" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 48 14 14]
# 	output #0 has shape [ 1 48 14 14]
# Layer "inception_4a/pool_proj" has 1 input(s) and 2 output(s)
# 	input #0 has shape [  1 480  14  14]
# 	output #0 has shape [  1 480  14  14]
# 	output #1 has shape [  1 480  14  14]
# Layer "inception_4a/relu_pool_proj" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 480  14  14]
# 	output #0 has shape [ 1 64 14 14]
# Layer "inception_4a/output" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 64 14 14]
# 	output #0 has shape [ 1 64 14 14]
# Layer "inception_4b/1x1" has 4 input(s) and 1 output(s)
# 	input #0 has shape [  1 192  14  14]
# 	input #1 has shape [  1 208  14  14]
# 	input #2 has shape [ 1 48 14 14]
# 	input #3 has shape [ 1 64 14 14]
# 	output #0 has shape [  1 512  14  14]
# Layer "inception_4b/relu_1x1" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [  1 160  14  14]
# Layer "inception_4b/3x3_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 160  14  14]
# 	output #0 has shape [  1 160  14  14]
# Layer "inception_4b/relu_3x3_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [  1 112  14  14]
# Layer "inception_4b/3x3" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 112  14  14]
# 	output #0 has shape [  1 112  14  14]
# Layer "inception_4b/relu_3x3" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 112  14  14]
# 	output #0 has shape [  1 224  14  14]
# Layer "inception_4b/5x5_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 224  14  14]
# 	output #0 has shape [  1 224  14  14]
# Layer "inception_4b/relu_5x5_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [ 1 24 14 14]
# Layer "inception_4b/5x5" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 24 14 14]
# 	output #0 has shape [ 1 24 14 14]
# Layer "inception_4b/relu_5x5" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 24 14 14]
# 	output #0 has shape [ 1 64 14 14]
# Layer "inception_4b/pool" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 64 14 14]
# 	output #0 has shape [ 1 64 14 14]
# Layer "inception_4b/pool_proj" has 1 input(s) and 2 output(s)
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [  1 512  14  14]
# 	output #1 has shape [  1 512  14  14]
# Layer "inception_4b/relu_pool_proj" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [ 1 64 14 14]
# Layer "inception_4b/output" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 64 14 14]
# 	output #0 has shape [ 1 64 14 14]
# Layer "inception_4c/1x1" has 4 input(s) and 1 output(s)
# 	input #0 has shape [  1 160  14  14]
# 	input #1 has shape [  1 224  14  14]
# 	input #2 has shape [ 1 64 14 14]
# 	input #3 has shape [ 1 64 14 14]
# 	output #0 has shape [  1 512  14  14]
# Layer "inception_4c/relu_1x1" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [  1 128  14  14]
# Layer "inception_4c/3x3_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 128  14  14]
# 	output #0 has shape [  1 128  14  14]
# Layer "inception_4c/relu_3x3_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [  1 128  14  14]
# Layer "inception_4c/3x3" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 128  14  14]
# 	output #0 has shape [  1 128  14  14]
# Layer "inception_4c/relu_3x3" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 128  14  14]
# 	output #0 has shape [  1 256  14  14]
# Layer "inception_4c/5x5_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
# Layer "inception_4c/relu_5x5_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [ 1 24 14 14]
# Layer "inception_4c/5x5" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 24 14 14]
# 	output #0 has shape [ 1 24 14 14]
# Layer "inception_4c/relu_5x5" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 24 14 14]
# 	output #0 has shape [ 1 64 14 14]
# Layer "inception_4c/pool" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 64 14 14]
# 	output #0 has shape [ 1 64 14 14]
# Layer "inception_4c/pool_proj" has 1 input(s) and 2 output(s)
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [  1 512  14  14]
# 	output #1 has shape [  1 512  14  14]
# Layer "inception_4c/relu_pool_proj" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [ 1 64 14 14]
# Layer "inception_4c/output" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 64 14 14]
# 	output #0 has shape [ 1 64 14 14]
# Layer "inception_4d/1x1" has 4 input(s) and 1 output(s)
# 	input #0 has shape [  1 128  14  14]
# 	input #1 has shape [  1 256  14  14]
# 	input #2 has shape [ 1 64 14 14]
# 	input #3 has shape [ 1 64 14 14]
# 	output #0 has shape [  1 512  14  14]
# Layer "inception_4d/relu_1x1" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [  1 112  14  14]
# Layer "inception_4d/3x3_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 112  14  14]
# 	output #0 has shape [  1 112  14  14]
# Layer "inception_4d/relu_3x3_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [  1 144  14  14]
# Layer "inception_4d/3x3" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 144  14  14]
# 	output #0 has shape [  1 144  14  14]
# Layer "inception_4d/relu_3x3" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 144  14  14]
# 	output #0 has shape [  1 288  14  14]
# Layer "inception_4d/5x5_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 288  14  14]
# 	output #0 has shape [  1 288  14  14]
# Layer "inception_4d/relu_5x5_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [ 1 32 14 14]
# Layer "inception_4d/5x5" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 32 14 14]
# 	output #0 has shape [ 1 32 14 14]
# Layer "inception_4d/relu_5x5" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 32 14 14]
# 	output #0 has shape [ 1 64 14 14]
# Layer "inception_4d/pool" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 64 14 14]
# 	output #0 has shape [ 1 64 14 14]
# Layer "inception_4d/pool_proj" has 1 input(s) and 2 output(s)
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [  1 512  14  14]
# 	output #1 has shape [  1 512  14  14]
# Layer "inception_4d/relu_pool_proj" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 512  14  14]
# 	output #0 has shape [ 1 64 14 14]
# Layer "inception_4d/output" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 64 14 14]
# 	output #0 has shape [ 1 64 14 14]
# Layer "inception_4e/1x1" has 4 input(s) and 1 output(s)
# 	input #0 has shape [  1 112  14  14]
# 	input #1 has shape [  1 288  14  14]
# 	input #2 has shape [ 1 64 14 14]
# 	input #3 has shape [ 1 64 14 14]
# 	output #0 has shape [  1 528  14  14]
# Layer "inception_4e/relu_1x1" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 528  14  14]
# 	output #0 has shape [  1 256  14  14]
# Layer "inception_4e/3x3_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 256  14  14]
# 	output #0 has shape [  1 256  14  14]
# Layer "inception_4e/relu_3x3_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 528  14  14]
# 	output #0 has shape [  1 160  14  14]
# Layer "inception_4e/3x3" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 160  14  14]
# 	output #0 has shape [  1 160  14  14]
# Layer "inception_4e/relu_3x3" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 160  14  14]
# 	output #0 has shape [  1 320  14  14]
# Layer "inception_4e/5x5_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 320  14  14]
# 	output #0 has shape [  1 320  14  14]
# Layer "inception_4e/relu_5x5_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 528  14  14]
# 	output #0 has shape [ 1 32 14 14]
# Layer "inception_4e/5x5" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 32 14 14]
# 	output #0 has shape [ 1 32 14 14]
# Layer "inception_4e/relu_5x5" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 32 14 14]
# 	output #0 has shape [  1 128  14  14]
# Layer "inception_4e/pool" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 128  14  14]
# 	output #0 has shape [  1 128  14  14]
# Layer "inception_4e/pool_proj" has 1 input(s) and 2 output(s)
# 	input #0 has shape [  1 528  14  14]
# 	output #0 has shape [  1 528  14  14]
# 	output #1 has shape [  1 528  14  14]
# Layer "inception_4e/relu_pool_proj" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 528  14  14]
# 	output #0 has shape [  1 128  14  14]
# Layer "inception_4e/output" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 128  14  14]
# 	output #0 has shape [  1 128  14  14]
# Layer "pool4/3x3_s2" has 4 input(s) and 1 output(s)
# 	input #0 has shape [  1 256  14  14]
# 	input #1 has shape [  1 320  14  14]
# 	input #2 has shape [  1 128  14  14]
# 	input #3 has shape [  1 128  14  14]
# 	output #0 has shape [  1 832  14  14]
# Layer "inception_5a/1x1" has 1 input(s) and 2 output(s)
# 	input #0 has shape [  1 832  14  14]
# 	output #0 has shape [  1 832   7   7]
# 	output #1 has shape [  1 832   7   7]
# Layer "inception_5a/relu_1x1" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 832   7   7]
# 	output #0 has shape [  1 256   7   7]
# Layer "inception_5a/3x3_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 256   7   7]
# 	output #0 has shape [  1 256   7   7]
# Layer "inception_5a/relu_3x3_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 832   7   7]
# 	output #0 has shape [  1 160   7   7]
# Layer "inception_5a/3x3" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 160   7   7]
# 	output #0 has shape [  1 160   7   7]
# Layer "inception_5a/relu_3x3" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 160   7   7]
# 	output #0 has shape [  1 320   7   7]
# Layer "inception_5a/5x5_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 320   7   7]
# 	output #0 has shape [  1 320   7   7]
# Layer "inception_5a/relu_5x5_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 832   7   7]
# 	output #0 has shape [ 1 32  7  7]
# Layer "inception_5a/5x5" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 32  7  7]
# 	output #0 has shape [ 1 32  7  7]
# Layer "inception_5a/relu_5x5" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 32  7  7]
# 	output #0 has shape [  1 128   7   7]
# Layer "inception_5a/pool" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 128   7   7]
# 	output #0 has shape [  1 128   7   7]
# Layer "inception_5a/pool_proj" has 1 input(s) and 2 output(s)
# 	input #0 has shape [  1 832   7   7]
# 	output #0 has shape [  1 832   7   7]
# 	output #1 has shape [  1 832   7   7]
# Layer "inception_5a/relu_pool_proj" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 832   7   7]
# 	output #0 has shape [  1 128   7   7]
# Layer "inception_5a/output" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 128   7   7]
# 	output #0 has shape [  1 128   7   7]
# Layer "inception_5b/1x1" has 4 input(s) and 1 output(s)
# 	input #0 has shape [  1 256   7   7]
# 	input #1 has shape [  1 320   7   7]
# 	input #2 has shape [  1 128   7   7]
# 	input #3 has shape [  1 128   7   7]
# 	output #0 has shape [  1 832   7   7]
# Layer "inception_5b/relu_1x1" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 832   7   7]
# 	output #0 has shape [  1 384   7   7]
# Layer "inception_5b/3x3_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 384   7   7]
# 	output #0 has shape [  1 384   7   7]
# Layer "inception_5b/relu_3x3_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 832   7   7]
# 	output #0 has shape [  1 192   7   7]
# Layer "inception_5b/3x3" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 192   7   7]
# 	output #0 has shape [  1 192   7   7]
# Layer "inception_5b/relu_3x3" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 192   7   7]
# 	output #0 has shape [  1 384   7   7]
# Layer "inception_5b/5x5_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 384   7   7]
# 	output #0 has shape [  1 384   7   7]
# Layer "inception_5b/relu_5x5_reduce" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 832   7   7]
# 	output #0 has shape [ 1 48  7  7]
# Layer "inception_5b/5x5" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 48  7  7]
# 	output #0 has shape [ 1 48  7  7]
# Layer "inception_5b/relu_5x5" has 1 input(s) and 1 output(s)
# 	input #0 has shape [ 1 48  7  7]
# 	output #0 has shape [  1 128   7   7]
# Layer "inception_5b/pool" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 128   7   7]
# 	output #0 has shape [  1 128   7   7]
# Layer "inception_5b/pool_proj" has 1 input(s) and 2 output(s)
# 	input #0 has shape [  1 832   7   7]
# 	output #0 has shape [  1 832   7   7]
# 	output #1 has shape [  1 832   7   7]
# Layer "inception_5b/relu_pool_proj" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 832   7   7]
# 	output #0 has shape [  1 128   7   7]
# Layer "inception_5b/output" has 1 input(s) and 1 output(s)
# 	input #0 has shape [  1 128   7   7]
# 	output #0 has shape [  1 128   7   7]
# Layer "pool5/7x7_s1" has 4 input(s) and 1 output(s)
# 	input #0 has shape [  1 384   7   7]
# 	input #1 has shape [  1 384   7   7]
# 	input #2 has shape [  1 128   7   7]
# 	input #3 has shape [  1 128   7   7]
# 	output #0 has shape [   1 1024    7    7]
# Layer "pool5/drop_7x7_s1" has 1 input(s) and 1 output(s)
# 	input #0 has shape [   1 1024    7    7]
# 	output #0 has shape [   1 1024    1    1]
# Layer "loss3/classifier" has 1 input(s) and 1 output(s)
# 	input #0 has shape [   1 1024    1    1]
# 	output #0 has shape [   1 1024    1    1]
# Layer "prob" has 1 input(s) and 1 output(s)
# 	input #0 has shape [   1 1024    1    1]
# 	output #0 has shape [   1 1000]
